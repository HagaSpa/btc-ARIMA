# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy import stats
import statsmodels.api as sm
import warnings
from itertools import product
from datetime import datetime

# %%
# Load data
## Weighted_Priceをとりあえずfloat64で固定
df = pd.read_csv('bitstampUSD_1-min_data_2012-01-01_to_2020-09-14.csv', dtype={'c': np.float64})
df.head()
# Out:
#     Timestamp  Open  High   Low  Close  Volume_(BTC)  Volume_(Currency)  \
# 0  1325317920  4.39  4.39  4.39   4.39      0.455581                2.0
# 1  1325317980   NaN   NaN   NaN    NaN           NaN                NaN
# 2  1325318040   NaN   NaN   NaN    NaN           NaN                NaN
# 3  1325318100   NaN   NaN   NaN    NaN           NaN                NaN
# 4  1325318160   NaN   NaN   NaN    NaN           NaN                NaN
#
#    Weighted_Price
# 0            4.39
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
# Unix-time to 
df.Timestamp = pd.to_datetime(df.Timestamp, unit='s')

# Resampling to daily frequency
df.index = df.Timestamp

df = df.resample('D').mean()

# Resampling to monthly frequency
df_month = df.resample('M').mean()

# Resampling to annual frequency
df_year = df.resample('A-DEC').mean()

# Resampling to quarterly frequency
df_Q = df.resample('Q-DEC').mean()

# %%
# PLOTS
fig = plt.figure(figsize=[15, 7])
plt.suptitle('Bitcoin exchanges, mean USD', fontsize=22)

plt.subplot(221)
plt.plot(df.Weighted_Price, '-', label='By Days')
plt.legend()

plt.subplot(222)
plt.plot(df_month.Weighted_Price, '-', label='By Months')
plt.legend()

plt.subplot(223)
plt.plot(df_Q.Weighted_Price, '-', label='By Quarters')
plt.legend()

plt.subplot(224)
plt.plot(df_year.Weighted_Price, '-', label='By Years')
plt.legend()

# plt.tight_layout()
plt.show()

# %% [markdown]
# ## ☝️　日、月、四半期、年でそれぞれ切り分けて、波形を表示してるだけ。

# %%
# Stationarity check and STL-decomposition of the series
plt.figure(figsize=[15,7])

# Seasonal decomposition using moving averages.
sm.tsa.seasonal_decompose(df_month.Weighted_Price).plot()
print("Dickey–Fuller test: p=%f" % sm.tsa.stattools.adfuller(df_month.Weighted_Price)[1])
plt.show()
# Out:
# Dickey–Fuller test: p=0.617866

# %% [markdown]
# ## ☝️ 月で見た波形がどういった性質を持っているのか、移動平均を用いてそれっぽい特徴？を可視化してる感じ？？ 知らんけど
#
# おそらくどんな特徴を持っているかを以下3つの要因に切り分けて表示している。
#
# * Trend
#  * まあ普通にトレンドじゃん
# * Seasonal
#  * 季節性?? 季節に相関した性質みたいなイメージ。
# * Resid
#  * **それ以外？？単純にTrendでもSeasonalでもないやつってこと？？**

# %%
# Box-Cox Transformations
df_month['Weighted_Price_box'], lmbda = stats.boxcox(df_month.Weighted_Price)
print("Dickey–Fuller test: p=%f" % sm.tsa.stattools.adfuller(df_month.Weighted_Price)[1])
# Out:
# Dickey–Fuller test: p=0.617866

# %% [markdown]
# ## ☝️ Box Cox 変換
# - 正規分布をとるためにBox-Cox変換をしている
#  - 正規分布をとることでそのデータの平均値の付近に集積するような分布に変換している？
#    - [その分布の確率変数は中心極限定理により正規分布にしたがう。](https://ja.wikipedia.org/wiki/%E6%AD%A3%E8%A6%8F%E5%88%86%E5%B8%83)
#      - は？
#
# ### 結局ここで何やりたいの？？
# 多分ここでやりたいことは正規分布に変換することで、正規分布に従う確率変数以外を落としてる？？
#
# > p=0.617866
#
# そもそもこの数字は何なわけ？？

# %%
# Seasonal differentiation
df_month['prices_box_diff'] = df_month.Weighted_Price_box - df_month.Weighted_Price_box.shift(12)
print("Dickey–Fuller test: p=%f" % sm.tsa.stattools.adfuller(df_month.prices_box_diff[12:])[1])
# Out:
# Dickey–Fuller test: p=0.288535

# %% [markdown]
# ## ☝️ Seasonal differentiation
# - 季節性の違い??
#   - 季節と季節の差分が上記数字と解釈した。
#   - **いやどの季節とどの季節よ？？　夏と冬とかそういうこと？？**

# %%
# Regular differentiation
df_month['prices_box_diff2'] = df_month.prices_box_diff - df_month.prices_box_diff.shift(1)
plt.figure(figsize=(15,7))

# STL-decomposition
sm.tsa.seasonal_decompose(df_month.prices_box_diff2[13:]).plot()   
print("Dickey–Fuller test: p=%f" % sm.tsa.stattools.adfuller(df_month.prices_box_diff2[13:])[1])

plt.show()
# Out:
# Dickey–Fuller test: p=0.000002

# %% [markdown]
# ## ☝️ Regular differentiation
#
# - Seasonal-Trend decomposition (STL)
#   - 季節性のトレンドをいかに分解している？
#
# - Trend
#   - トレンド
# - Seasonal
#   - 季節性
# - Resid
#   - 残差

# %%
# Model Selection

# Initial approximation of parameters using Autocorrelation and Partial Autocorrelation Plots
plt.figure(figsize=(15,7))
ax = plt.subplot(211)
sm.graphics.tsa.plot_acf(df_month.prices_box_diff2[13:].values.squeeze(), lags=48, ax=ax)
ax = plt.subplot(212)

# ValueError: Can only compute partial correlations for lags up to 50% of the sample size. The requested nlags 48 must be < 46.
# sm.graphics.tsa.plot_pacf(df_month.prices_box_diff2[13:].values.squeeze(), lags=48, ax=ax)

sm.graphics.tsa.plot_pacf(df_month.prices_box_diff2[13:].values.squeeze(), ax=ax)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## ☝️ Model Selection
# モデルの選定？
#
# ### Initial approximation of parameters using Autocorrelation and Partial Autocorrelation Plots
# - 自己相関および偏自己相関プロットを使用したパラメーターの初期近似
#   - は？
#
# ### Auto Correlation
# - 自己相関
#
# ### Partial AutoCorrelation
# - 偏自己相関
#
# 大体+-/0.2位になっていることがわかる。

# %%
# Initial approximation of parameters
Qs = range(0, 2)
qs = range(0, 3)
Ps = range(0, 3)
ps = range(0, 3)
D=1
d=1
parameters = product(ps, qs, Ps, Qs)
parameters_list = list(parameters)
len(parameters_list)

# Model Selection
results = []
best_aic = float("inf")
warnings.filterwarnings('ignore')
for param in parameters_list:
    try:
        model=sm.tsa.statespace.SARIMAX(df_month.Weighted_Price_box, order=(param[0], d, param[1]), 
                                        seasonal_order=(param[2], D, param[3], 12)).fit(disp=-1)
    except ValueError:
        print('wrong parameters:', param)
        continue
    aic = model.aic
    # aicは低いほうがbestらしい
    if aic < best_aic:
        best_model = model
        best_aic = aic
        best_param = param
    results.append([param, model.aic])

# %%
# Best Models
result_table = pd.DataFrame(results)
result_table.columns = ['parameters', 'aic']
print(result_table.sort_values(by = 'aic', ascending=True).head())
print(best_model.summary())
# Out:
#       parameters         aic
# 11  (0, 1, 2, 1)  198.825567
# 23  (1, 0, 2, 1)  198.882307
# 19  (1, 0, 0, 1)  199.158279
# 21  (1, 0, 1, 1)  199.434531
# 7   (0, 1, 0, 1)  199.517923
#                                      SARIMAX Results
# ...
# Dep. Variable:                 Weighted_Price_box   No. Observations:                  106
# Model:             SARIMAX(0, 1, 1)x(2, 1, 1, 12)   Log Likelihood                 -94.413
# Date:                            Sun, 27 Dec 2020   AIC                            198.826
# Time:                                    03:09:49   BIC                            211.489
# Sample:                                12-31-2011   HQIC                           203.939
#                                      - 09-30-2020
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## ☝️ Initial approximation of parameters
# ## Best Models
# - 一番いいモデルを選択していると思われる。

# %%
# Analysis of residues

# STL-decomposition
plt.figure(figsize=(15,7))
plt.subplot(211)
best_model.resid[13:].plot()
plt.ylabel(u'Residuals')
ax = plt.subplot(212)
sm.graphics.tsa.plot_acf(best_model.resid[13:].values.squeeze(), lags=48, ax=ax)

print("Dickey–Fuller test:: p=%f" % sm.tsa.stattools.adfuller(best_model.resid[13:])[1])

plt.tight_layout()
plt.show()
# Out:
# Dickey–Fuller test:: p=0.000000

# %% [markdown]
# ## ☝️ Analysis of residues
# - 残差に対してSTL（季節性傾向）の分析を行う??

# %%
# Prediction

# Inverse Box-Cox Transformation Function
def invboxcox(y,lmbda):
   if lmbda == 0:
      return(np.exp(y))
   else:
      return(np.exp(np.log(lmbda*y+1)/lmbda))

# %%
# Prediction
df_month2 = df_month[['Weighted_Price']]

# 2020-09-30まで
date_list = [datetime(2017, 6, 30), datetime(2017, 7, 31), datetime(2017, 8, 31), datetime(2017, 9, 30), 
             datetime(2017, 10, 31), datetime(2017, 11, 30), datetime(2017, 12, 31), datetime(2018, 1, 31),
             datetime(2018, 1, 28)]
future = pd.DataFrame(index=date_list, columns= df_month.columns)
df_month2 = pd.concat([df_month2, future])

# 最後までpredictionしたいからendを指定しなにする？
df_month2['forecast'] = invboxcox(best_model.predict(start=0), lmbda)
#df_month2['forecast'] = invboxcox(best_model.predict(start=0, end=75), lmbda)

plt.figure(figsize=(17,9))
df_month2.Weighted_Price.plot()
df_month2.forecast.plot(color='r', ls='--', label='Predicted Weighted_Price')
plt.legend()
plt.title('Bitcoin exchanges, by months')
plt.ylabel('mean USD')
plt.show()

# %% [markdown]
# ## ☝️ Prediction
# - 2018年前半のpredictionがバグってる
# - ちょくちょく線が消えてるのはなんなんだろ？？
# - まあ波形は近いけど全然当たってない風に思える。。。

# %% [markdown]
# # 所感
# おそらく時系列予測を用いた流れとして以下のような感じなのだと認識した。
#
# 1. 現象の波形を可視化し、標準偏差をとることでその波形に起因しているであろう要素（季節性、トレンドなど）を探す。
#   - 簡単に言うとその波形がその波形である要因を探す。
#
# 2. ARIMAモデルを使って、パラメータを変えながら学習する。
#   - 一番数字がいいやつを採用する。
#
# 3. 2で選択したモデルを使って予測をする。
